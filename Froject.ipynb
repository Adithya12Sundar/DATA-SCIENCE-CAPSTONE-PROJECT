# %%
import pandas as pd

# %%
#data loading
read_data= pd.read_csv('/content/nrsa1819_data_for_populationestimates.csv')

# %%
#column overview
read_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1851 entries, 0 to 1850
# Data columns (total 48 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   UID               1851 non-null   int64
#  1   SITE_ID           1851 non-null   object
#  2   DATE_COL          1851 non-null   object
#  3   VISIT_NO          1851 non-null   int64
#  4   SITESAMP          1851 non-null   object
#  5   UNIQUE_ID         1851 non-null   object
#  6   DSGN_CYCLE        1851 non-null   object
#  7   AG_ECO3           1851 non-null   object
#  8   AG_ECO9           1851 non-null   object
#  9   EPA_REG           1851 non-null   object
#  10  EVAL_CAT          1851 non-null   object
#  11  FED_NONFED        1851 non-null   object
#  12  FS_EW             1851 non-null   object
#  13  HUC2_NM           1851 non-null   object
#  14  LAT_DD83          1851 non-null   float64
#  15  LON_DD83          1851 non-null   float64
# ...

# %%
#identify numeric columns (9)
num_column= ['UID' , 'VISIT_NO' , 'LAT_DD83', 'LON_DD83' , 'WGT_TP', 'XCOORD', 'YCOORD', 'YEAR']

# %%
#dataframe overview
read_data
# Out:
#           UID         SITE_ID    DATE_COL  VISIT_NO SITESAMP     UNIQUE_ID  \
# 0     2014737  NRS18_OK_10062  06/20/2018         1        Y  NRS_OK-10090
# 1     2012488  NRS18_OK_10431  06/25/2018         1        Y  NRS_OK-10206
# 2     2012489  NRS18_OK_10025  07/02/2018         1        Y  NRS_OK-10180
# 3     2012490  NRS18_WI_10091  07/02/2018         1        Y  NRS_WI-10211
# 4     2012491  NRS18_WI_10006  07/12/2018         1        Y  NRS_WI-10087
# ...       ...             ...         ...       ...      ...           ...
# 1846  2014722  NRS18_NC_10007  09/29/2019         1        Y  NRS_NC-10050
# 1847  2014723  NRS18_KS_10027  10/07/2019         1        Y  NRS_KS-10208
# 1848  2014724  NRS18_KS_10097  10/01/2019         1        Y  NRS_KS-10246
# 1849  2014734  NRS18_MN_10261  10/02/2019         1        Y  NRS_MN-10220
# 1850  2011534  NRS18_KS_10050  10/08/2019         1        Y  NRS_KS-10050
#
# ...

# %%
#value distribution in the dataframe
read_data.nunique()
# Out:
# UID                 1851
# SITE_ID             1851
# DATE_COL             249
# VISIT_NO               1
# SITESAMP               1
# UNIQUE_ID           1851
# DSGN_CYCLE             1
# AG_ECO3                3
# AG_ECO9                9
# EPA_REG               10
# EVAL_CAT               1
# FED_NONFED             2
# FS_EW                  3
# HUC2_NM               21
# LAT_DD83            1851
# LON_DD83            1851
# MAJ_BAS_NM            16
# MIS_BAS_NM             7
# MISS_BASIN             2
# OWN_NARS              11
# PSTL_CODE             48
# STRAH_CAT              4
# URBN_NRS18             2
# USFS                   2
# WGT_TP               313
# XCOORD              1851
# YCOORD              1851
# ACID_COND              4
# ANC_COND               4
# BEDSED_COND            4
# BENT_MMI_COND          4
# CYLSPER_DETECT         2
# CYLSPER_EPA_COND       1
# ENT_1X_STV_COND        3
# FISH_MMI_COND          4
# HG_COND                3
# INSTRMCVR_COND         4
# ...

# %%
unique_ness = read_data.nunique()

# %%
#identify the null value distribution
read_data.isnull().sum()
# Out:
# UID                    0
# SITE_ID                0
# DATE_COL               0
# VISIT_NO               0
# SITESAMP               0
# UNIQUE_ID              0
# DSGN_CYCLE             0
# AG_ECO3                0
# AG_ECO9                0
# EPA_REG                0
# EVAL_CAT               0
# FED_NONFED             0
# FS_EW                  0
# HUC2_NM                0
# LAT_DD83               0
# LON_DD83               0
# MAJ_BAS_NM             0
# MIS_BAS_NM             0
# MISS_BASIN             0
# OWN_NARS               0
# PSTL_CODE              0
# STRAH_CAT              0
# URBN_NRS18             0
# USFS                   0
# WGT_TP                 0
# XCOORD                 0
# YCOORD                 0
# ACID_COND              0
# ANC_COND            1840
# BEDSED_COND            0
# BENT_MMI_COND          0
# CYLSPER_DETECT         0
# CYLSPER_EPA_COND       0
# ENT_1X_STV_COND        0
# FISH_MMI_COND          0
# HG_COND                0
# INSTRMCVR_COND         0
# ...

# %%
read_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1851 entries, 0 to 1850
# Data columns (total 48 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   UID               1851 non-null   int64
#  1   SITE_ID           1851 non-null   object
#  2   DATE_COL          1851 non-null   object
#  3   VISIT_NO          1851 non-null   int64
#  4   SITESAMP          1851 non-null   object
#  5   UNIQUE_ID         1851 non-null   object
#  6   DSGN_CYCLE        1851 non-null   object
#  7   AG_ECO3           1851 non-null   object
#  8   AG_ECO9           1851 non-null   object
#  9   EPA_REG           1851 non-null   object
#  10  EVAL_CAT          1851 non-null   object
#  11  FED_NONFED        1851 non-null   object
#  12  FS_EW             1851 non-null   object
#  13  HUC2_NM           1851 non-null   object
#  14  LAT_DD83          1851 non-null   float64
#  15  LON_DD83          1851 non-null   float64
# ...

# %%
empt = []

# %%
desired_columns = []

# %%
#removing column with 1 unique value or 1851 unique value as they are of less importance
read_data.nunique()
for i in read_data.columns:
  if read_data[i].nunique()!=1:
    if read_data[i].nunique()!=1851:
      desired_columns.append(i)

# %%
read_dataframe= read_data[desired_columns]

# %%
#observing the unique value
read_dataframe.nunique()
# Out:
# DATE_COL           249
# AG_ECO3              3
# AG_ECO9              9
# EPA_REG             10
# FED_NONFED           2
# FS_EW                3
# HUC2_NM             21
# MAJ_BAS_NM          16
# MIS_BAS_NM           7
# MISS_BASIN           2
# OWN_NARS            11
# PSTL_CODE           48
# STRAH_CAT            4
# URBN_NRS18           2
# USFS                 2
# WGT_TP             313
# ACID_COND            4
# ANC_COND             4
# BEDSED_COND          4
# BENT_MMI_COND        4
# CYLSPER_DETECT       2
# ENT_1X_STV_COND      3
# FISH_MMI_COND        4
# HG_COND              3
# INSTRMCVR_COND       4
# MICX_DETECT          2
# NTL_COND             4
# OE_COND              5
# PTL_COND             3
# RIPDIST_COND         4
# RIPVEG_COND          4
# SAL_COND             4
# SALINITY_CLASS       5
# YEAR                 2
# dtype: int64

# %%
read_dataframe
# Out:
#         DATE_COL AG_ECO3 AG_ECO9    EPA_REG FED_NONFED     FS_EW  \
# 0     06/20/2018  PLNLOW     SPL  Region_06    Federal  Not_USFS
# 1     06/25/2018  PLNLOW     TPL  Region_06    Federal  Not_USFS
# 2     07/02/2018  PLNLOW     CPL  Region_06    Federal  Not_USFS
# 3     07/02/2018  PLNLOW     TPL  Region_05    Federal  Not_USFS
# 4     07/12/2018  PLNLOW     UMW  Region_05    Federal  Not_USFS
# ...          ...     ...     ...        ...        ...       ...
# 1846  09/29/2019   EHIGH     SAP  Region_04    Federal  Not_USFS
# 1847  10/07/2019  PLNLOW     SPL  Region_07    Federal  Not_USFS
# 1848  10/01/2019  PLNLOW     TPL  Region_07    Federal  Not_USFS
# 1849  10/02/2019  PLNLOW     UMW  Region_05    Federal  Not_USFS
# 1850  10/08/2019  PLNLOW     SPL  Region_07    Federal  Not_USFS
#
#                           HUC2_NM                 MAJ_BAS_NM  \
# 0       Arkansas-Red-White Region  Arkansas-White-Red Region
# ...

# %%
#dropped ANC_Condition since it had 1800 null values and studying it would be irrelevant
read_dataframe = read_dataframe.drop(['ANC_COND'], axis =1)
read_dataframe = read_dataframe[read_dataframe["FISH_MMI_COND"]!='Not Assessed']

# %%
import matplotlib.pyplot as plt

# %%
#plt.bar(read_dataframe.isnull().sum().index  read_dataframe.isnull().sum()[0])
#plt.show()

# %%
#removing entries target varaibewl value is not assessed
read_dataframe = read_dataframe[read_dataframe["FISH_MMI_COND"]!='Not Assessed']

# %%
#columns that are significant
impcols = read_dataframe.columns

# %%
#preparing the independent variable
X = read_dataframe.drop(['FISH_MMI_COND'], axis = 1)
X
# Out:
#         DATE_COL AG_ECO3 AG_ECO9    EPA_REG FED_NONFED     FS_EW  \
# 0     06/20/2018  PLNLOW     SPL  Region_06    Federal  Not_USFS
# 1     06/25/2018  PLNLOW     TPL  Region_06    Federal  Not_USFS
# 3     07/02/2018  PLNLOW     TPL  Region_05    Federal  Not_USFS
# 5     07/16/2018  PLNLOW     SPL  Region_06    Federal  Not_USFS
# 6     07/16/2018  PLNLOW     UMW  Region_05    Federal  Not_USFS
# ...          ...     ...     ...        ...        ...       ...
# 1843  09/26/2019  PLNLOW     NPL  Region_08    Federal  Not_USFS
# 1846  09/29/2019   EHIGH     SAP  Region_04    Federal  Not_USFS
# 1847  10/07/2019  PLNLOW     SPL  Region_07    Federal  Not_USFS
# 1848  10/01/2019  PLNLOW     TPL  Region_07    Federal  Not_USFS
# 1850  10/08/2019  PLNLOW     SPL  Region_07    Federal  Not_USFS
#
#                           HUC2_NM                 MAJ_BAS_NM  \
# 0       Arkansas-Red-White Region  Arkansas-White-Red Region
# ...

# %%
#preparating the target variable
y = read_dataframe['FISH_MMI_COND']

# %%
#identifying the balance of different value for the target variabel
distribution = y.value_counts()

# %%
#distribution = pd.DataFrame(o)

# %%
distribution
# Out:
# FISH_MMI_COND
# Poor    660
# Good    479
# Fair    354
# Name: count, dtype: int64

# %%
#Normalzing the only numeric feature
from sklearn.preprocessing import MinMaxScaler

# %%
std  = MinMaxScaler()

# %%
X['WGT_TP'] = std.fit_transform(X[['WGT_TP']])

# %%
#checking the column past the normalization
X['WGT_TP']
# Out:
# 0       0.039391
# 1       0.055084
# 3       0.139404
# 5       0.023025
# 6       0.028946
#           ...
# 1843    0.009357
# 1846    0.014309
# 1847    0.042355
# 1848    0.048782
# 1850    0.042355
# Name: WGT_TP, Length: 1493, dtype: float64

# %%
dataX = pd.get_dummies(X.drop(['WGT_TP'], axis =1))

# %%
import numpy as np
import seaborn as sns

# %%
#sns.heatmap(ui.corr() , cmap = plt.cm.gray)
#plt.show()

# %%
dataX['WGT_TP'] = X['WGT_TP']

# %%
import pandas as pd

# %%
#numeric label encoding ofo the target
f = pd.factorize(y)
f
# Out:
# (array([0, 1, 1, ..., 2, 0, 2]),
#  Index(['Fair', 'Good', 'Poor'], dtype='object'))

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
arf = RandomForestClassifier(n_estimators = 130)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(dataX,f[0],test_size = 0.2,random_state = 40)

# %%
arf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=130)

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix,ConfusionMatrixDisplay

# %%
x_train
# Out:
#       YEAR  DATE_COL_04/26/2019  DATE_COL_04/27/2019  DATE_COL_04/28/2019  \
# 97    2018                False                False                False
# 1353  2019                False                False                False
# 1752  2019                False                False                False
# 763   2018                False                False                False
# 1769  2019                False                False                False
# ...    ...                  ...                  ...                  ...
# 1256  2019                False                False                False
# 202   2018                False                False                False
# 11    2018                False                False                False
# 263   2018                False                False                False
# 1676  2019                False                False                False
#
#       DATE_COL_04/29/2019  DATE_COL_04/30/2019  DATE_COL_05/01/2019  \
# ...

# %%
result_y = arf.predict(x_test)

# %%
accuracy_score(result_y  , y_test)
# Out:
# 0.6287625418060201

# %%
precision_score(y_test, result_y,average = None)
# Out:
# array([0.48      , 0.64      , 0.64367816])

# %%
recall_score(y_test , result_y, average =None)
# Out:
# array([0.19354839, 0.65306122, 0.8057554 ])

# %%
confusion_matrix(y_test, result_y)
# Out:
# array([[ 12,  18,  32],
#        [  4,  64,  30],
#        [  9,  18, 112]])

# %%
184/299
# Out:
# 0.6153846153846154

# %%
from sklearn.svm import SVC
scv = SVC(C=1,kernel = 'rbf')

# %%
scv.fit(x_train,y_train)
# Out:
# SVC(C=1)

# %%
result__y = scv.predict(x_test)

# %%
accuracy_score(y_test , result__y)
# Out:
# 0.46488294314381273

# %%
precision_score(y_test , result__y,average = None)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# array([0.        , 0.        , 0.46488294])

# %%
recall_score(y_test, result__y, average = None)
# Out:
# array([0., 0., 1.])

# %%
f1_score(y_test , result__y, average = None)
# Out:
# array([0.       , 0.       , 0.6347032])

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
yy = knn.predict(x_test)

# %%
accuracy_score(y_test , yy)
# Out:
# 0.5618729096989966

# %%
recall_score(y_test , yy , average = None)
# Out:
# array([0.33870968, 0.65306122, 0.5971223 ])

# %%
precision_score(y_test , yy, average = None)
# Out:
# array([0.30434783, 0.57142857, 0.70338983])

# %%
f1_score(y_test , yy, average  = None)
# Out:
# array([0.32061069, 0.60952381, 0.6459144 ])

# %%
confusion_matrix(y_test , yy)
# Out:
# array([[21, 22, 19],
#        [18, 64, 16],
#        [30, 26, 83]])

# %%
from sklearn.tree import DecisionTreeClassifier
dcc = DecisionTreeClassifier()

# %%
dcc.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_rest = dcc.predict(x_test)

# %%
accuracy_score(y_test , y_rest)
# Out:
# 0.5150501672240803

# %%
precision_score(y_test , y_rest, average = None)
# Out:
# array([0.2625    , 0.57608696, 0.62992126])

# %%
recall_score(y_test , y_rest, average = None)
# Out:
# array([0.33870968, 0.54081633, 0.57553957])

# %%
f1_score(y_test , y_rest, average = None)
# Out:
# array([0.29577465, 0.55789474, 0.60150376])

# %%
from sklearn.linear_model import LogisticRegression

# %%
confusion_matrix(y_test , y_rest)
# Out:
# array([[21, 15, 26],
#        [24, 53, 21],
#        [35, 24, 80]])

# %%
lgr = LogisticRegression()

# %%
lgr.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
yy_t= lgr.predict(x_test)

# %%
print(accuracy_score(y_test, yy_t))
print(recall_score(y_test, yy_t,average = None))
# Out:
# 0.5986622073578596
# [0.19354839 0.6122449  0.76978417]

# %%
precision_score(y_test , yy_t, average = None)
f1_score(y_test, yy_t, average = None)
# Out:
# array([0.25531915, 0.60606061, 0.69934641])

# %%
confusion_matrix(y_test, yy_t)
# Out:
# array([[ 12,  22,  28],
#        [  6,  60,  32],
#        [ 14,  18, 107]])

# %%
from sklearn.ensemble import GradientBoostingClassifier
rf = RandomForestClassifier(n_estimators=100, random_state=42)
gb = GradientBoostingClassifier(n_estimators=100, random_state=42)
lr = LogisticRegression(max_iter=1000)
svc = SVC(probability=True, kernel='rbf', random_state=42)

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import StackingClassifier

# %%
voting_soft = VotingClassifier(
    estimators=[('rf', rf), ('gb', gb), ('lr', lr), ('svc', svc)],
    voting='soft'
)

# %%
# Hard voting
voting_hard = VotingClassifier(
    estimators=[('rf', rf), ('gb', gb), ('lr', lr), ('svc', svc)],
    voting='hard'
)

# %%
voting_weighted = VotingClassifier(
    estimators=[('rf', rf), ('gb', gb), ('lr', lr), ('svc', svc)],
    voting='soft',
    weights=[2, 2, 1, 1]
)

# %%
stack = StackingClassifier(
    estimators=[('rf', rf), ('gb', gb), ('svc',svc)],
    final_estimator=LogisticRegression(),
    passthrough=True
)

# %%
models = {'voting_soft': voting_soft,'voting_hard': voting_hard,'voting_weighted':voting_weighted, 'stack':stack}

# %%
for name, model in models.items():
  model.fit(x_train,y_train)
  y_pred = model.predict(x_test)
  acc = accuracy_score(y_test,y_pred)
  print(acc)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.6220735785953178
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
#randomforestclassifier cm
sns.heatmap(confusion_matrix(y__test, y_test), xticklabels = ['Fair','Good','Poor'], yticklabels = ['Fair','Good','Poor'], annot = True, fmt = 'g' )
plt.show()

# %%
sns.heatmap(confusion_matrix(y_test, y__test) , xticklabels=['Fair','Good','Poor'], yticklabels = ['Fair','Good','Poor'])

# %%
sns.heatmap(knn_matrix, xticklabels = ['Fair', 'Good', 'Poor'], yticklabels = ['Fair','Good','Poor'], annot = True)
plt.xlabel("Predcited_Value")
plt.ylabel("Real_Value")
plt.show()

# %%
newcm  = confusion_matrix(y_test, yy_test)

# %%
sns.heatmap(newcm, xticklabels= ['Fair', 'Good', 'Poor'], yticklabels = ['Fair', 'Good','Poor'], annot = True)
plt.xlabel("Model Value")
plt.ylabel("Actual Value")
plt.title("The Prediction of o vector classifier")
plt.show()

# %%
#import joblib

# %%
#joblib.dump(rf, 'kbc.pkl')

# %%
#from sklearn.metrics import accuracy_score
